# %%
import requests

url = "https://wttr.in/Delhi?format=j1"
response = requests.get(url)
data = response.text

# %%
response.status_code

# %%
response.json()

# %%
response.text

# %%
df=spark.createDataFrame(data)

# %%
df.describe

# %%
df.display()

# %%
df1=spark.createDataFrame([data])

# %%
df1.display()

# %%
df1.write.mode("overwrite").csv
